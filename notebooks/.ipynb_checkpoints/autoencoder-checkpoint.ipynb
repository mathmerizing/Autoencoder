# %% [markdown]
# # How to train a Denoising Autoencoder for MNIST

# %% [markdown]
# ## Imports

# %%
import os
os.chdir("../")

# importing functions and classes from our framework
from activations import Identity, Sigmoid, Tanh, ReLU, LeakyReLU, Softmax, Activation
from loss import MSE, CrossEntropy
from dataset import Dataset
from optimizer import Adam, SGD
from nn import MLP
from autoencoder import Autoencoder
from gan import GAN
from layers import Dense

# other imports
import time
import numpy as np
import logging
logging.basicConfig(level=logging.DEBUG , format='[%(asctime)s] - [%(levelname)s] - %(message)s')

# import the plotting library
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
from bokeh.plotting import figure 
output_notebook()

# %load_ext tensorboard
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Training

# %%
dataset_mnist = Dataset(name = "mnist", train_size = 60000, test_size = 10000, batch_size = 10)
NOISE = 0.1

# set the learning rate and optimizer for training
optimizer = Adam(1e-2)

encoder = MLP()
encoder.addLayer(Dense(inputDim = 28 * 28, outputDim = 50, activation = ReLU(), optimizer = optimizer))

decoder = MLP()
decoder.addLayer(Dense(inputDim = 50, outputDim = 28 * 28, activation = Sigmoid(), optimizer = optimizer))

autoencoder = Autoencoder(encoder, decoder, noise = NOISE)

print(autoencoder)
# Out:
# -------------------- MULTI LAYER PERCEPTRON (MLP) --------------------
#
# HIDDEN LAYERS = 0
# TOTAL PARAMETERS = 79234
#
#  *** 1. Layer: ***
# -----------------------
# DENSE 784 -> 50 [ReLU]
# -----------------------
# Total parameters: 39250
# ---> WEIGHTS: (50, 784)
# ---> BIASES: (50,)
# -----------------------
#
#  *** 2. Layer: ***
# --------------------------
# DENSE 50 -> 784 [Sigmoid]
# --------------------------
# Total parameters: 39984
# ---> WEIGHTS: (784, 50)
# ---> BIASES: (784,)
# --------------------------
#
# ----------------------------------------------------------------------

# %%
# define callback dictionary, in which loss and accuracy callbacks are stored
my_callbacks = {}#{"loss": loss_callback}

# %%
autoencoder.train(dataset_mnist, loss = MSE(), metrics = ["train_loss", "test_loss"], tensorboard = False, epochs = 20, callbacks = my_callbacks)
# Out:
# [2020-07-05 20:40:29,349] - [DEBUG] -  *** EPOCH 1/20 ***
# [2020-07-05 20:40:49,510] - [DEBUG] -  *** EPOCH 2/20 ***
# [2020-07-05 20:41:09,303] - [DEBUG] -  *** EPOCH 3/20 ***
# [2020-07-05 20:41:28,531] - [DEBUG] -  *** EPOCH 4/20 ***
# [2020-07-05 20:41:48,432] - [DEBUG] -  *** EPOCH 5/20 ***
# [2020-07-05 20:42:08,570] - [DEBUG] -  *** EPOCH 6/20 ***
# [2020-07-05 20:42:29,265] - [DEBUG] -  *** EPOCH 7/20 ***
# [2020-07-05 20:42:49,763] - [DEBUG] -  *** EPOCH 8/20 ***
# [2020-07-05 20:43:10,358] - [DEBUG] -  *** EPOCH 9/20 ***
# [2020-07-05 20:43:31,044] - [DEBUG] -  *** EPOCH 10/20 ***
# [2020-07-05 20:43:52,549] - [DEBUG] -  *** EPOCH 11/20 ***
# [2020-07-05 20:44:12,007] - [DEBUG] -  *** EPOCH 12/20 ***
# [2020-07-05 20:44:31,077] - [DEBUG] -  *** EPOCH 13/20 ***
# [2020-07-05 20:44:49,990] - [DEBUG] -  *** EPOCH 14/20 ***
# [2020-07-05 20:45:08,974] - [DEBUG] -  *** EPOCH 15/20 ***
# [2020-07-05 20:45:27,951] - [DEBUG] -  *** EPOCH 16/20 ***
# ...

# %% [markdown]
# ## Visualize the quality of the autoencoder

# %%
import matplotlib.pyplot as plt
dataset2 = Dataset(name = "mnist", train_size = 60000, test_size = 10000, batch_size = 1)

# %%
sample = next(dataset2.batches(autoencoder = True, noise = NOISE))
plt.imshow(sample[1][0].reshape(28,28))
plt.show()

# %%
output = autoencoder.feedforward(sample[1][0])

# %%
plt.imshow(output.reshape(28,28))
plt.show()
